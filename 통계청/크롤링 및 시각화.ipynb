# %%
import requests
import json
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
 

headers = {"X-Naver-Client-Id": "FqwaeS_b2rvI7M9Xfz7C", 
           "X-Naver-Client-Secret":"YWnsei3psz"}

url = "https://openapi.naver.com/v1/datalab/shopping/categories"

categories = [
    {"name": "패션의류", "param": [ "50000000"]},
      {"name": "화장품/미용", "param": [ "50000002"]},
      {"name": "가구/인테리어", "param": [ "50000004"]},
      {"name": "출산/육아", "param": [ "50000005"]},
      {"name": "식품", "param": [ "50000006"]},
      {"name": "스포츠/레저", "param": [ "50000007"]},
     {"name": "패션잡화", "param": [ "50000001"]}
  ]

data = {
  "startDate": "2019-01-01",
  "endDate": "2020-12-31",
  "timeUnit": "month",
  "ages" :  ["20","30"],
  "category": [
      {"name": "디지털/가전", "param": [ "50000003"]},
        {"name": "생활/건강", "param": [ "50000008"]}
      
  ]
}

def change_index(df, column_name):
    df = df.set_index("period")
    df.columns = [column_name]
    return df

response = requests.post(url, headers=headers, json=data)

results = response.json()["results"]


df_a = change_index(pd.DataFrame(results[0]["data"]), "디지털/가전")
df_b = change_index(pd.DataFrame(results[1]["data"]), "생활/건강")

df_all = pd.merge(df_a, df_b, left_on="period", right_on="period")

for category in categories:
    if len(data["category"]) > 2:
        data["category"].pop(2)
    data["category"].append(category)
    
    result = requests.post(url, headers=headers, json=data)

    results = result.json()["results"]

    df = change_index(pd.DataFrame(results[2]["data"]), category["name"]) 

    df_all = pd.merge(df_all, df, left_on="period", right_on="period")
    

mpl.rc('font', family='Malgun Gothic')
plt.figure(figsize=[10,5])
#plt.xticks(rotation=60)
sns.lineplot(data=df_all, markers=True, dashes=False)
plt.legend(loc=1)

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24 entries, 2019-01-01 to 2020-12-01
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   디지털/가전   24 non-null     float64
#  1   생활/건강    24 non-null     float64
#  2   패션의류     24 non-null     float64
#  3   화장품/미용   24 non-null     float64
#  4   가구/인테리어  24 non-null     float64
#  5   출산/육아    24 non-null     float64
#  6   식품       24 non-null     float64
#  7   스포츠/레저   24 non-null     float64
#  8   패션잡화     24 non-null     float64
# dtypes: float64(9)
# memory usage: 2.5+ KB

# %%
# 패션의류

headers = {"X-Naver-Client-Id": "FqwaeS_b2rvI7M9Xfz7C", 
           "X-Naver-Client-Secret":"YWnsei3psz"}

url = "https://openapi.naver.com/v1/datalab/shopping/categories"

categories = [
      {"name": "여성의류", "param": [ "50000167"]},
      {"name": "여성언더웨어/잠옷", "param": [ "50000168"]}
      
      
  ]

data = {
  "startDate": "2019-01-01",
  "endDate": "2020-12-31",
  "timeUnit": "month",
  "ages" :  ["20","30"],
  "category": [
      {"name": "남성의류", "param": [ "50000004"]},
      {"name": "남성언더웨어/잠옷", "param": [ "50000170"]}
  ]
}

def change_index(df, column_name):
    df = df.set_index("period")
    df.columns = [column_name]
    return df

response = requests.post(url, headers=headers, json=data)

results = response.json()["results"]


df_a = change_index(pd.DataFrame(results[0]["data"]), "남성의류")
df_b = change_index(pd.DataFrame(results[1]["data"]), "남성언더웨어/잠옷")

df_all = pd.merge(df_a, df_b, left_on="period", right_on="period")

for category in categories:
    if len(data["category"]) > 2:
        data["category"].pop(2)
    data["category"].append(category)
    
    result = requests.post(url, headers=headers, json=data)

    results = result.json()["results"]

    df = change_index(pd.DataFrame(results[2]["data"]), category["name"]) 

    df_all = pd.merge(df_all, df, left_on="period", right_on="period")
    

mpl.rc('font', family='Malgun Gothic')
plt.figure(figsize=[10,5])
plt.xticks(rotation=60)
sns.lineplot(data=df_all, markers=True, dashes=False)
# Out:
# <AxesSubplot:xlabel='period'>

# %%
# 패션잡화

headers = {"X-Naver-Client-Id": "FqwaeS_b2rvI7M9Xfz7C", 
           "X-Naver-Client-Secret":"YWnsei3psz"}

url = "https://openapi.naver.com/v1/datalab/shopping/categories"

categories = [
    {"name": "여성신발", "param": [ "50000173"]},
    {"name": "남성신발", "param": [ "50000174"]},
    {"name": "신발용품", "param": [ "50000175"]},
    {"name": "여성가방", "param": [ "50000176"]},
    {"name": "남성가방", "param": [ "50000177"]},
    {"name": "여행용가방/소품", "param": [ "50000178"]},
    {"name": "지갑", "param": [ "50000179"]},
    {"name": "벨트", "param": [ "50000180"]},
    {"name": "모자", "param": [ "50000181"]},
    {"name": "장갑", "param": [ "50000182"]},
    {"name": "양말", "param": [ "50000166"]},
    {"name": "선글라스/안경테", "param": [ "50000183"]},
    {"name": "헤어액세서리", "param": [ "50000184"]},
    {"name": "패션소품", "param": [ "50000185"]},
    {"name": "시계", "param": [ "50000186"]}
    
  ]

data = {
  "startDate": "2019-01-01",
  "endDate": "2020-12-31",
  "timeUnit": "month",
  "ages" :  ["50","60"],
  "category": [
      {"name": "순금", "param": [ "50000188"]},
      {"name": "주얼리", "param": [ "50000189"]},
  ]
}

def change_index(df, column_name):
    df = df.set_index("period")
    df.columns = [column_name]
    return df

response = requests.post(url, headers=headers, json=data)

results = response.json()["results"]


df_a = change_index(pd.DataFrame(results[0]["data"]), "순금")
df_b = change_index(pd.DataFrame(results[1]["data"]), "주얼리")

df_all = pd.merge(df_a, df_b, left_on="period", right_on="period")

for category in categories:
    if len(data["category"]) > 2:
        data["category"].pop(2)
    data["category"].append(category)
    
    result = requests.post(url, headers=headers, json=data)

    results = result.json()["results"]

    df = change_index(pd.DataFrame(results[2]["data"]), category["name"]) 

    df_all = pd.merge(df_all, df, left_on="period", right_on="period")
    

mpl.rc('font', family='Malgun Gothic')
plt.figure(figsize=[15,5])
plt.xticks(rotation=60)
sns.lineplot(data=df_all, markers=True, dashes=False)
# Out:
# <AxesSubplot:xlabel='period'>

# %%
# 출산/육아

headers = {"X-Naver-Client-Id": "FqwaeS_b2rvI7M9Xfz7C", 
           "X-Naver-Client-Secret":"YWnsei3psz"}

url = "https://openapi.naver.com/v1/datalab/shopping/categories"

categories = [
    {"name": "안전용품", "param": [ "50000130"]},
    {"name": "신생아의류", "param": [ "50000137"]},
    {"name": "유아동의류", "param": [ "50000138"]},
    {"name": "유아동언더웨어/잠옷", "param": [ "50007135"]},
    {"name": "유아동잡화", "param": [ "50000139"]},
    {"name": "유아발육용품", "param": [ "50000141"]},
    {"name": "완구/매트", "param": [ "50000142"]}
    
  ]

data = {
  "startDate": "2019-01-01",
  "endDate": "2020-12-31",
  "timeUnit": "month",
  "ages" :  ["20","30"],
  "category": [
      {"name": "인형", "param": [ "50000143"]},
    {"name": "교재/서적", "param": [ "50000144"]}
  ]
}

def change_index(df, column_name):
    df = df.set_index("period")
    df.columns = [column_name]
    return df

response = requests.post(url, headers=headers, json=data)

results = response.json()["results"]


df_a = change_index(pd.DataFrame(results[0]["data"]), "인형")
df_b = change_index(pd.DataFrame(results[1]["data"]), "교재/서적")

df_all = pd.merge(df_a, df_b, left_on="period", right_on="period")

for category in categories:
    if len(data["category"]) > 2:
        data["category"].pop(2)
    data["category"].append(category)
    
    result = requests.post(url, headers=headers, json=data)

    results = result.json()["results"]

    df = change_index(pd.DataFrame(results[2]["data"]), category["name"]) 

    df_all = pd.merge(df_all, df, left_on="period", right_on="period")
    

mpl.rc('font', family='Malgun Gothic')
plt.figure(figsize=[15,5])
plt.xticks(rotation=60)
sns.lineplot(data=df_all, markers=True, dashes=False)
# Out:
# <AxesSubplot:xlabel='period'>

# %%
# 가구/인테리어

headers = {"X-Naver-Client-Id": "FqwaeS_b2rvI7M9Xfz7C", 
           "X-Naver-Client-Secret":"YWnsei3psz"}

url = "https://openapi.naver.com/v1/datalab/shopping/categories"

categories = [
     {"name": "인테리어소품", "param": [ "50000108"]},
    
    {"name": "거실가구", "param": [ "50000101"]},
    #{"name": "주방가구", "param": [ "50000102"]}
    {"name": "홈데코", "param": [ "50000154"]}
    #{"name": "수납가구", "param": [ "50000103"]},
    #{"name": "서재/사무용가구", "param": [ "50000105"]},
    #{"name": "아웃도어가구", "param": [ "50000106"]},
    
    
    #{"name": "카페트/러그", "param": [ "50000112"]}
  ]

data = {
  "startDate": "2019-01-01",
  "endDate": "2020-12-31",
  "timeUnit": "month",
  "ages" :  ["50","60"],
  "category": [
     {"name": "침실가구", "param": [ "50000100"]},
      {"name": "DIY자재/용품", "param": [ "50000107"]}
    
   
  ]
}

def change_index(df, column_name):
    df = df.set_index("period")
    df.columns = [column_name]
    return df

response = requests.post(url, headers=headers, json=data)

results = response.json()["results"]


df_a = change_index(pd.DataFrame(results[0]["data"]), "침실가구")
df_b = change_index(pd.DataFrame(results[1]["data"]), "DIY자재/용품")

df_all = pd.merge(df_a, df_b, left_on="period", right_on="period")

for category in categories:
    if len(data["category"]) > 2:
        data["category"].pop(2)
    data["category"].append(category)
    
    result = requests.post(url, headers=headers, json=data)

    results = result.json()["results"]

    df = change_index(pd.DataFrame(results[2]["data"]), category["name"]) 

    df_all = pd.merge(df_all, df, left_on="period", right_on="period")
    

mpl.rc('font', family='Malgun Gothic')
plt.figure(figsize=[10,5])
plt.xticks(rotation=60)
sns.lineplot(data=df_all, markers=True, dashes=False)
# Out:
# <AxesSubplot:xlabel='period'>

# %%
# 식품

headers = {"X-Naver-Client-Id": "FqwaeS_b2rvI7M9Xfz7C", 
           "X-Naver-Client-Secret":"YWnsei3psz"}

url = "https://openapi.naver.com/v1/datalab/shopping/categories"

categories = [
    {"name": "축산", "param": [ "50000145"]},
    {"name": "수산", "param": [ "50000159"]},
    {"name": "농산물", "param": [ "50000160"]},
    #{"name": "반찬", "param": [ "50000146"]},
    #{"name": "음료", "param": [ "50000148"]},
    #{"name": "과자", "param": [ "50000149"]},
    #{"name": "아이스크림/빙수", "param": [ "50000025"]},
    {"name": "가공식품", "param": [ "50000150"]},
    {"name": "냉동/간편조리식품", "param": [ "50000026"]}
    
  ]

data = {
  "startDate": "2019-01-01",
  "endDate": "2020-12-31",
  "timeUnit": "month",
  "ages" :  ["20","30"],
  "category": [
    {"name": "건강식품", "param": [ "50000023"]},
      {"name": "다이어트식품", "param": [ "50000024"]}
  ]
}

def change_index(df, column_name):
    df = df.set_index("period")
    df.columns = [column_name]
    return df

response = requests.post(url, headers=headers, json=data)

results = response.json()["results"]


df_a = change_index(pd.DataFrame(results[0]["data"]), "건강식품")
df_b = change_index(pd.DataFrame(results[1]["data"]), "다이어트식품")

df_all = pd.merge(df_a, df_b, left_on="period", right_on="period")

for category in categories:
    if len(data["category"]) > 2:
        data["category"].pop(2)
    data["category"].append(category)
    
    result = requests.post(url, headers=headers, json=data)

    results = result.json()["results"]

    df = change_index(pd.DataFrame(results[2]["data"]), category["name"]) 

    df_all = pd.merge(df_all, df, left_on="period", right_on="period")
    

mpl.rc('font', family='Malgun Gothic')
plt.figure(figsize=[10,5])
plt.xticks(rotation=60)
sns.lineplot(data=df_all, markers=True, dashes=False)
# Out:
# <AxesSubplot:xlabel='period'>

# %%
# 디지털/가전

headers = {"X-Naver-Client-Id": "FqwaeS_b2rvI7M9Xfz7C", 
           "X-Naver-Client-Secret":"YWnsei3psz"}

url = "https://openapi.naver.com/v1/datalab/shopping/categories"

categories = [
    {"name": "카메라/캠코더용품", "param": [ "50000206"]},
    {"name": "영상가전", "param": [ "50000208"]},
    {"name": "음향가전", "param": [ "50000209"]},
    {"name": "생활가전", "param": [ "50000210"]},
    {"name": "이미용가전", "param": [ "50000211"]},
    {"name": "주방가전", "param": [ "50000213"]},
    {"name": "자동차기기", "param": [ "50000214"]},
    {"name": "계절가전", "param": [ "50000212"]},
    {"name": "게임기/타이틀", "param": [ "50000088"]},
    {"name": "PC", "param": [ "50000089"]},
    {"name": "노트북", "param": [ "50000151"]},
    {"name": "태블릿PC", "param": [ "50000152"]},
    {"name": "멀티미디어장비", "param": [ "50000095"]}
  ]

data = {
  "startDate": "2019-01-01",
  "endDate": "2020-12-31",
  "timeUnit": "month",
  "ages" :  ["50","60"],
  "category": [
      {"name": "휴대폰", "param": [ "50000204"]},
    {"name": "모니터", "param": [ "50000153"]}
  ]
}

def change_index(df, column_name):
    df = df.set_index("period")
    df.columns = [column_name]
    return df

response = requests.post(url, headers=headers, json=data)

results = response.json()["results"]


df_a = change_index(pd.DataFrame(results[0]["data"]), "휴대폰")
df_b = change_index(pd.DataFrame(results[1]["data"]), "모니터")

df_all = pd.merge(df_a, df_b, left_on="period", right_on="period")

for category in categories:
    if len(data["category"]) > 2:
        data["category"].pop(2)
    data["category"].append(category)
    
    result = requests.post(url, headers=headers, json=data)

    results = result.json()["results"]

    df = change_index(pd.DataFrame(results[2]["data"]), category["name"]) 

    df_all = pd.merge(df_all, df, left_on="period", right_on="period")
    

mpl.rc('font', family='Malgun Gothic')
plt.figure(figsize=[15,5])
plt.xticks(rotation=60)
sns.lineplot(data=df_all, markers=True, dashes=False)
# Out:
# <AxesSubplot:xlabel='period'>

# %%
# 스포츠/레저

headers = {"X-Naver-Client-Id": "FqwaeS_b2rvI7M9Xfz7C", 
           "X-Naver-Client-Secret":"YWnsei3psz"}

url = "https://openapi.naver.com/v1/datalab/shopping/categories"

categories = [
    {"name": "등산", "param": [ "50000027"]},
    {"name": "캠핑", "param": [ "50000028"]},
    {"name": "골프", "param": [ "50000029"]},
    #{"name": "자전거", "param": [ "50000161"]},
    #{"name": "스키/보드", "param": [ "50000162"]},
    {"name": "낚시", "param": [ "50000163"]},
    #{"name": "수영", "param": [ "50000164"]},
    
    #{"name": "오토바이/스쿠터", "param": [ "50000035"]},
    #{"name": "축구", "param": [ "50000036"]},
    #{"name": "야구", "param": [ "50000037"]},
    #{"name": "농구", "param": [ "50000038"]},
    #{"name": "탁구", "param": [ "50000040"]},
    #{"name": "배드민턴", "param": [ "50000041"]},
    #{"name": "테니스", "param": [ "50000042"]},

    

  ]

data = {
  "startDate": "2019-01-01",
  "endDate": "2020-12-31",
  "timeUnit": "month",
  "ages" :  ["20","30"],
  "category": [
      {"name": "헬스", "param": [ "50000030"]},
    {"name": "요가/필라테스", "param": [ "50000031"]}
     # {"name": "볼링", "param": [ "50000045"]},
    #{"name": "댄스", "param": [ "50000048"]}
  ]
}

def change_index(df, column_name):
    df = df.set_index("period")
    df.columns = [column_name]
    return df

response = requests.post(url, headers=headers, json=data)

results = response.json()["results"]


df_a = change_index(pd.DataFrame(results[0]["data"]), "헬스")
df_b = change_index(pd.DataFrame(results[1]["data"]), "요가/필라테스")

df_all = pd.merge(df_a, df_b, left_on="period", right_on="period")

for category in categories:
    if len(data["category"]) > 2:
        data["category"].pop(2)
    data["category"].append(category)
    
    result = requests.post(url, headers=headers, json=data)

    results = result.json()["results"]

    df = change_index(pd.DataFrame(results[2]["data"]), category["name"]) 

    df_all = pd.merge(df_all, df, left_on="period", right_on="period")
    

mpl.rc('font', family='Malgun Gothic')
plt.figure(figsize=[10,5])
plt.xticks(rotation=60)
sns.lineplot(data=df_all, markers=True, dashes=False)
# Out:
# <AxesSubplot:xlabel='period'>

# %%
# 스포츠/레저

headers = {"X-Naver-Client-Id": "FqwaeS_b2rvI7M9Xfz7C", 
           "X-Naver-Client-Secret":"YWnsei3psz"}

url = "https://openapi.naver.com/v1/datalab/shopping/categories"

categories = [
    {"name": "등산화", "param": [ "50001768"]},
    {"name": "등산장비", "param": [ "50001098"]},
    {"name": "등산잡화", "param": [ "50001097"]}
    

  ]

data = {
  "startDate": "2019-01-01",
  "endDate": "2020-12-31",
  "timeUnit": "month",
  "ages" :  ["20","30"],
  "category": [
     {"name": "등산의류", "param": [ "50001096"]},
     {"name": "기타등산장비", "param": [ "50001303"]},
  ]
}

def change_index(df, column_name):
    df = df.set_index("period")
    df.columns = [column_name]
    return df

response = requests.post(url, headers=headers, json=data)

results = response.json()["results"]


df_a = change_index(pd.DataFrame(results[0]["data"]), "등산의류")
df_b = change_index(pd.DataFrame(results[1]["data"]), "기타등산장비")

df_all = pd.merge(df_a, df_b, left_on="period", right_on="period")

for category in categories:
    if len(data["category"]) > 2:
        data["category"].pop(2)
    data["category"].append(category)
    
    result = requests.post(url, headers=headers, json=data)

    results = result.json()["results"]

    df = change_index(pd.DataFrame(results[2]["data"]), category["name"]) 

    df_all = pd.merge(df_all, df, left_on="period", right_on="period")
    

mpl.rc('font', family='Malgun Gothic')
plt.figure(figsize=[15,5])
plt.xticks(rotation=60)
sns.lineplot(data=df_all, markers=True, dashes=False)
# Out:
# <AxesSubplot:xlabel='period'>

# %% [markdown]
# ### 예측

# %%
#오프라인
ts = pd.read_csv('df_all.csv')
ts.set_index(ts['period'],inplace = True)
ts = ts['스포츠/레저']

# %%
'''
Generate a Random Walk process.
:parameter
    :param y0: num - starting value
    :param n: num - length of process
    :param ymin: num - limit
    :param ymax: num - limit
'''
def utils_generate_rw(y0, n, sigma, ymin=None, ymax=None):
    rw = [y0]
    for t in range(1, n):
        yt = rw[t-1] + np.random.normal(0,sigma)
        if (ymax is not None) and (yt > ymax):
            yt = rw[t-1] - abs(np.random.normal(0,sigma))
        elif (ymin is not None) and (yt < ymin):
            yt = rw[t-1] + abs(np.random.normal(0,sigma))
        rw.append(yt)
    return rw

# %%
'''
Generate dates to index predictions.
:parameter
    :param start: str - "yyyy-mm-dd"
    :param end: str - "yyyy-mm-dd"
    :param n: num - length of index
    :param freq: None or str - 'B' business day, 'D' daily, 'W' 
                 weekly, 'M' monthly, 'A' annual, 'Q' quarterly
'''
def utils_generate_indexdate(start, end=None, n=None, freq="D"):
    if end is not None:
        index = pd.date_range(start=start, end=end, freq=freq)
    else:
        index = pd.date_range(start=start, periods=n, freq=freq)
    index = index[1:]
    print("--- generating index date --> start:", index[0], 
          "| end:", index[-1], "| len:", len(index), "---")
    return index.strftime('%Y-%m')

# %%
'''
Plot unknown future forecast.
'''
def utils_plot_forecast(dtf, zoom=30, figsize=(15,5)):
    ## interval
    dtf["residuals"] = dtf["ts"] - dtf["model"]
    dtf["conf_int_low"] = dtf["forecast"] - 1.96*dtf["residuals"].std()
    dtf["conf_int_up"] = dtf["forecast"] + 1.96*dtf["residuals"].std()
    fig, ax = plt.subplots(nrows=1, ncols=2, figsize=figsize)
    
    ## entire series
    dtf[["ts","forecast"]].plot(color=["black","red"], grid=True, ax=ax[0], title="2021년 예측")
    ax[0].fill_between(x=dtf.index, y1=dtf['conf_int_low'], y2=dtf['conf_int_up'], color='b', alpha=0.3) 
          
    ## focus on last
    first_idx = dtf[pd.notnull(dtf["forecast"])].index[0]
    first_loc = dtf.index.tolist().index(first_idx)
    zoom_idx = dtf.index[first_loc-zoom]
    dtf.loc[zoom_idx:][["ts","forecast"]].plot(color=["black","red"], grid=True, ax=ax[1], title="2021년 상반기 추이 예측")
    ax[1].fill_between(x=dtf.loc[zoom_idx:].index, y1=dtf.loc[zoom_idx:]['conf_int_low'], 
                       y2=dtf.loc[zoom_idx:]['conf_int_up'], color='b', alpha=0.3)
    
    
    plt.show()
    return dtf[["ts","model","residuals","conf_int_low","forecast","conf_int_up"]]

# %%
'''
Forecast unknown future.
'''
def forecast_rw(ts, pred_ahead=None, end=None, freq="D", zoom=30, 
                figsize=(15,5)):
    ## fit
    diff_ts = ts - ts.shift(1)
    sigma = diff_ts.std()
    rw = utils_generate_rw(y0=ts[0], n=len(ts), sigma=sigma, 
                           ymin=ts.min(), ymax=ts.max())
    dtf = ts.to_frame(name="ts").merge(
                pd.DataFrame(rw, index=ts.index, columns=["model"]), 
                             how='left', left_index=True, 
                             right_index=True)
    ## index
    index = utils_generate_indexdate(start=ts.index[-1], end=end, 
                                      n=pred_ahead, freq=freq)
    ## forecast
    preds = utils_generate_rw(y0=ts[-1], n=len(index), sigma=sigma, 
                              ymin=ts.min(), ymax=ts.max())
    dtf = dtf.append(pd.DataFrame(data=preds, index=index, 
                                  columns=["forecast"]))
    ## plot
    dtf = utils_plot_forecast(dtf, zoom=zoom)
    return dtf

# %%
#온라인
ts =df_all['생활/건강']

# %%
future = forecast_rw(ts, end="2021-06-30", freq="M", zoom=30)
# Out:
# --- generating index date --> start: 2021-01-31 00:00:00 | end: 2021-06-30 00:00:00 | len: 6 ---
